# %%
# $:> conda env create --file=env.yaml
# $:> conda activate discoverai_env
# $:> python --version

# %% [markdown]
# - Online Document
# - Search
# - OCR
# - OpenAI

# %% [markdown]
# # Imports

# %%
import sys
import os
import uuid
import re
import time
import requests
import random
import re
import ntpath
import json
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
get_ipython().run_line_magic('matplotlib', 'inline')
from PIL import Image
from io import BytesIO
import http.client, urllib.request, urllib.parse, urllib.error, base64
from pdf2image import convert_from_path

# AZURE - OCR
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__
from ocrlayout.bboxhelper import BBOXOCRResponse,BBoxHelper

# AZURE - Search
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient

# OpenAI
import openai

import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %% [markdown]
# ## :: config ::

# %%
def load_config(config_fp):
    with open(config_fp, "r") as f:
        config_data = json.load(fp=f)
        os.environ["STORAGE_NAME"] = config_data["STORAGE_NAME"]
        os.environ["STORAGE_CONN"] = config_data["STORAGE_CONN"]
        os.environ["OCR_KEY"] = config_data["OCR_KEY"]
        os.environ["OCR_ENDPOINT"] = config_data["OCR_ENDPOINT"]
        os.environ["OPENAI_KEY"] = config_data["OPENAI_KEY"]
        os.environ["STORAGE_NAME"] = config_data["STORAGE_NAME"]
        os.environ["SEARCH_ENDPOINT"] = config_data["SEARCH_ENDPOINT"]
        os.environ["INDEX_NAME"] = config_data["INDEX_NAME"]
        os.environ["SEARCH_KEY"] = config_data["SEARCH_KEY"]    
    return

load_config("azure_config.json")

# %% [markdown]
# # Data

# %%
# load data from AZURE-STORAGE-CONTAINER-BLOB ITEMS

blob_service_client = BlobServiceClient.from_connection_string(os.environ.get("STORAGE_CONN"))
container_client = blob_service_client.get_container_client("documents")
data={}
blobs_list = container_client.list_blobs()
for blob in blobs_list:
    print(blob.name)
    data[blob.name] = container_client.get_blob_client(blob.name).url

# %% [markdown]
# # OCR

# %% [markdown]
# #### Using READ API v3.2

# %% [markdown]
# API Readme:
#
# https://centraluseuap.dev.cognitive.microsoft.com/docs/services/computer-vision-v3-2/operations/5d986960601faab4bf452005

# %%
def run_azure_ocr_api(fp):
    
    key = os.environ.get("OCR_KEY")
    endpoint = os.environ.get("OCR_ENDPOINT")
    
    headers = {
        'Content-Type': 'application/json',
        'Ocp-Apim-Subscription-Key': key
    }

    params = {
        'language': 'en'
    }
    
    body = {"url": fp}
    
    # "https://{endpoint}/vision/v3.2/read/analyze[?language][&pages][&readingOrder][&model-version]"
    
    # Submit a request
    url_request = endpoint + "vision/v3.2/read/analyze"
    response = requests.post(url_request, headers=headers, params=params, json=body)
    if response.status_code == 202:
        
        # service has been submitted, now retrieve the operation-unique-id
        operation_location = response.headers["Operation-Location"]
        operation_id = operation_location.split("/")[-1]
        print("Success - Submitted a request | Operation ID: %s |" % operation_id)

        # get results
        url_readResults =  endpoint + "vision/v3.2/read/analyzeResults/" + operation_id
        while True:
            response = requests.get(url_readResults, headers=headers)
            if response.json()['status'].strip().lower() not in ['notstarted', 'running']:
                break
            print("Waiting for results...")
            time.sleep(1)
        print("Compiled results!")
        return response

    else:
        print("Failed to submit request! ERROR :: ", str(response.text))

# %%
# read-api-v3.2

api_output = run_azure_ocr_api(data["The Prospect of a Continued Correction.pdf"])
api_output.json()["analyzeResult"]["readResults"]

# %% [markdown]
# ### OCR Module

# %%
class run_ocr_process:
    
    def __init__(self, FILE_PATH):
        if not FILE_PATH.startswith(('https', 'http', 'www', 'ftp', 'localhost')) and not os.path.exists(FILE_PATH):
            raise Exception("ERROR: File not found!")

        self.supported_formats = ['png', 'jpg', 'jpeg', 'heic', 'gif', 'bmp', 'tiff', 'pdf', 'txt', 'md']
        
        self.file_path, \
        self.file_basename,  \
        self.file_ext = str(FILE_PATH), \
                        ntpath.basename(FILE_PATH).split(".")[0].lower().strip(), \
                        ntpath.basename(FILE_PATH).split(".")[1].lower().strip()
        
        if self.file_ext not in self.supported_formats:
            raise Exception("ERROR: Unsupported file format!")
            
        key = os.environ.get("OCR_KEY")
        self.endpoint = os.environ.get("OCR_ENDPOINT")

        # Set credentials & create client
        self.credentials = CognitiveServicesCredentials(key)
        self.client = ComputerVisionClient(self.endpoint, self.credentials)

        return
    
    
    def run_ocr(self):
        """
        Runs OCR READ API V3.2 using client libraries.
        :return: result - obj: Azure ReadAPI v3.2 response
        """
        start = time.time()
        response = None
        result = None

        if self.file_path.startswith(('https', 'http', 'www', 'ftp', 'localhost')):
            # > hosted doc url (blob)
            self.file_type = 'online'
            response = self.client.read(self.file_path, raw=True)

        elif self.file_ext in ['png', 'jpg', 'jpeg', 'heic', 'gif', 'bmp', 'tiff', 'pdf']:
            # > image/pdf
            fp = open(self.file_path,'rb')
            response = self.client.read_in_stream(fp, raw=True)
            fp.close()

        elif self.file_ext in ['txt', 'md']:
            # > local plain text files
            with open(self.file_path, "r") as f:
                response = f.readlines()

        elif self.file_ext in ['doc', 'docs', 'docx']:
            # > Word file - coming soon
            sys.exit()

        else:
            raise Exception("ERROR: Unsupported file format!")

        # Get the operation location and ID from the response:
        operation_location = response.headers["Operation-Location"]
        operation_id = operation_location.split("/")[-1]
        print("Success - Submitted a request | Operation ID: %s |" % operation_id)

        # read 'results' using operation-id:
        while True:
            result = self.client.get_read_result(operation_id)
            if result.status.lower () not in ['notstarted', 'running']:
                break
            print ('Waiting for result...')
            time.sleep(1)

        print("%%time taken(s): ", (time.time() - start) )
        return result
        
    
    def format_boundingBox(self, ocr_result):
        """
        Cleans and formats (sorting) on BB coordinates/font-size.
        :prarm:  ocr_result - obj: origninal Azure ReadAPI v3.2 response obj
        :return: bboxresponse.text - str: cleaned corpus (with delimitters & context info)
        
        ref - https://puthurr.github.io/
        
        """
        COMPUTERVISION_SUBSCRIPTION_KEY = os.environ["OCR_KEY"]
        COMPUTERVISION_LOCATION = "eastus"
        
        ocr_str = json.dumps(ocr_result.serialize())
        
        # Create BoundingBox OCR Response (intersect with coordinates)
        bboxresponse = BBoxHelper().processAzureOCRResponse(ocr_str)
        return bboxresponse.text


    def process_ocr_results(self, ocr_result):
        """
        Extracts meaningful info from Azure's ReadAPI v3.2 response object.
        :prarm:  ocr_result - obj: origninal Azure ReadAPI v3.2 response obj
        :return: output_df - pd.DataFrame: line-by-line text with BB coords; corpus_json - dict; ocr_output - dict;
        """
        # Displays text captured and its bounding box
        result = ocr_result
        output_df = pd.DataFrame()
        
        # Print the detected text, line by line
        if result.status == OperationStatusCodes.succeeded:
            
            for readResult in result.analyze_result.read_results:
                page_change_marker = "\n\n"
                for line in readResult.lines:
                    # print(line.text)
                    # print(">>", line.bounding_box)
                    """
                    bounding box:
                    X top left, Y top left, 
                    X top right, Y top right, 
                    X bottom right, Y bottom right, 
                    X bottom left, Y bottom left
                    """
                    data = {
                        "lines": page_change_marker + line.text,
                        "top_left_XY": (line.bounding_box[0], line.bounding_box[1]),
                        "top_right_XY": (line.bounding_box[2], line.bounding_box[3]),
                        "bottom_right_XY": (line.bounding_box[4], line.bounding_box[5]),
                        "bottom_left_XY": (line.bounding_box[6], line.bounding_box[7])
                    }                      
                    output_df = output_df.append(data, ignore_index=True)
                    page_change_marker=""
        
        
        # :: output ::
        #  'output_df'    : dataframe - stores line-by-line info with BB info XY (top-l, top-r, bottom-r, bottom-l)
        #  'corpus_json'  : dict - raw original response
        #  'ocr_output'   : dict - usable summarized-response 
        #
        corpus_json = result.as_dict()
        if self.file_ext=='pdf': 
            print("\nPDF file found! >> No. of pages= ", len(corpus_json['analyze_result']['read_results']) )
        
        ocr_output = {
            'title': self.file_basename + "." + self.file_ext,
            'format': self.file_ext,
            'isPdf': True if self.file_ext=='pdf' else False,
            'lines': output_df.to_dict(orient='records'),
            'corpus': "\n".join(output_df['lines'].tolist())
        }
        
        # CLEAN TEXT [ALTERNTATE] - formatiing Bounding Box using coordinates for sorting and positioning
        #   'corpus': self.format_boundingBox(ocr_result),
        
        return output_df, corpus_json, ocr_output
    
    
    def display_results(self, ocr_result):
        """
        Display BB overlapped on text. (**pdf needs poppler installed!**)
        :prarm:  ocr_result - obj: origninal Azure ReadAPI v3.2 response obj
        :return: None
        """
        
        result = ocr_result
        
        # Extract the word bounding boxes and text.
        word_infos=[]
        for readResult in result.analyze_result.read_results:
            for line in readResult.lines:
                for word_info in line.words:
                    word_infos.append(word_info)

        # Display the image and overlay it with the extracted text.
        plt.figure(figsize=(10, 8))
        image = Image.open(self.file_path)
        ax = plt.imshow(image, alpha=0.5)
        for word in word_infos:
            word = word.as_dict()
            bbox = [int(num) for num in word["bounding_box"]]
            text = word["text"]
            origin = (bbox[0], bbox[1])
            patch = Rectangle(origin, bbox[2], bbox[3],
                              fill=False, linewidth=2, color='y')
            ax.axes.add_patch(patch)
            plt.text(origin[0], origin[1], text, fontsize=20, weight="bold", va="top")
        plt.show()
        plt.axis("off")
        return
    
    
    def main(self):
        
        # run Azure's OCR
        ocr_result = self.run_ocr()
        
        # extract info
        output_df, corpus_json, ocr_output = self.process_ocr_results(ocr_result)
        
        if self.file_ext not in ['pdf'] and self.file_type!='online':
            self.display_results(ocr_result)
        
        return ocr_output, output_df

# %%
# demo

execute = run_ocr_process(data["The Prospect of a Continued Correction.pdf"])
ocr_output, output_df = execute.main()
# Out:
# Success - Submitted a request | Operation ID: 9507d8e2-831f-4892-a5aa-4c9db1ec3b31 |
# Waiting for result...
# %%time taken(s):  2.189833402633667
#
# PDF file found! >> No. of pages=  1

# %%
output_df
# Out:
#                                                 lines       top_left_XY  \
# 0          \n\nThe Prospect of a Continued Correction  (0.4918, 0.5676)
# 1                                         Mike Wilson  (0.4894, 1.0363)
# 2   Welcome to Thoughts on the Market. I'm Mike Wi...  (0.4891, 1.5051)
# 3   Strategist for Morgan Stanley. Along with my c...  (0.4934, 1.6613)
# 4   be talking about the latest trends in the fina...  (0.4967, 1.8176)
# 5                                                a.m.  (0.4949, 2.0009)
# 6                 in New York. So let's get after it.  (0.8692, 1.9738)
# 7   This past week tensions around Russia/Ukraine ...  (0.4918, 2.2863)
# 8   this occur, it's easy to simply throw up one's...  (0.4903, 2.4426)
# 9   not so sure that's a good idea, particularly i...  (0.4967, 2.5988)
# 10                                            growth.  (0.4923, 2.7559)
# 11  From here, though, the depth and duration of t...  (0.4997, 3.0676)
# 12  the magnitude of the slowdown in the first hal...  (0.4903, 3.2238)
# 13                                                can  (0.4965, 3.4072)
# 14  make this slowdown even worse, ultimately, we ...  (0.7894, 3.3801)
# 15  focused on for months will be the primary driv...  (0.4861, 3.5363)
# 16                                       much priced.  (0.4921, 3.6926)
# 17  While most economic and earnings forecasts do ...  (0.4891, 4.0051)
# 18  think there's a growing risk of greater disapp...  (0.4903, 4.1613)
# 19  slowing consumer demand as confidence remains ...  (0.4982, 4.3176)
# 20  about everything the consumer needs and wants....  (0.4949, 4.4738)
# 21                                           consumer  (0.4965, 4.6572)
# 22  will hold up better than the confidence survey...  (1.1576, 4.6301)
# 23  retail sales and credit card data remain robus...  (0.4994, 4.7863)
# 24  indicate no slowdown in demand, at least not y...  (0.4975, 4.9426)
# 25  that the risk of consumer slowdown remains hig...  (0.4903, 5.0988)
# 26  importantly, is the fact that supply is now ri...  (0.4975, 5.2551)
# 27  shortages, it could also lead to a return of p...  (0.4982, 5.4113)
# 28  pressures have been the greatest. That's poten...  (0.4967, 5.5676)
# 29  demand, in our view, if the improved supply re...  (0.4933, 5.7238)
# 30  is currently anticipated. In short, the order ...  (0.4975, 5.8801)
# 31                                                 as  (0.4949, 6.0634)
# 32                                    people believe.  (0.7197, 6.0363)
# 33  Overall, the technical picture is mixed also w...  (0.4899, 6.3488)
# 34  breath and havoc under the surface when the S&...   (0.4967, 6.505)
# 35                            In our experience, when  (6.0733, 6.5051)
# 36  such a divergence like this happens, it typica...  (0.4982, 6.6613)
# 37  average stock. In short, this correction looks...  (0.4949, 6.8176)
# 38  that equity markets are very oversold and sent...  (0.4903, 6.9738)
# 39  Russia Ukraine situation now weighing heavily ...  (0.4974, 7.1301)
# 40  tactical rally, but we acknowledge that uncert...  (0.4903, 7.2863)
# 41  The bottom line for us is that we really don't...  (0.4918, 7.5988)
# 42  it relates to the equity markets. However, we ...  (0.4975, 7.7551)
# 43  Therefore, we would look to sell strength into...  (0.4918, 7.9113)
# 44     geopolitical risk failing to escalate further.  (0.4923, 8.0676)
# 45  Thanks for listening. If you enjoy Thoughts on...  (0.4918, 8.3801)
# 46                                                 on  (0.4922, 8.5634)
# 47  the Apple Podcasts app. It helps more people t...  (0.7133, 8.5363)
#
#         top_right_XY   bottom_right_XY    bottom_left_XY
# 0   (3.3007, 0.5676)  (3.3007, 0.6901)  (0.4918, 0.6901)
# 1   (1.2935, 1.0363)   (1.2935, 1.133)   (0.4894, 1.133)
# 2   (7.7671, 1.5051)  (7.7671, 1.6283)  (0.4891, 1.6283)
# 3   (7.9107, 1.6613)  (7.9107, 1.7846)  (0.4934, 1.7846)
# 4   (7.9121, 1.8176)  (7.9121, 1.9408)  (0.4967, 1.9408)
# 5   (0.7568, 2.0009)  (0.7568, 2.0705)  (0.4949, 2.0705)
# 6   (3.4332, 1.9738)  (3.4332, 2.0971)  (0.8692, 2.0971)
# 7   (7.9871, 2.2863)  (7.9871, 2.4089)  (0.4918, 2.4089)
# 8   (7.9128, 2.4426)  (7.9128, 2.5655)  (0.4903, 2.5655)
# 9   (7.9896, 2.5988)  (7.9896, 2.7221)  (0.4967, 2.7221)
# 10  (0.9798, 2.7559)  (0.9798, 2.8783)  (0.4923, 2.8783)
# 11  (7.8414, 3.0676)  (7.8414, 3.1908)  (0.4997, 3.1908)
# 12  (7.9901, 3.2238)  (7.9901, 3.3471)  (0.4903, 3.3471)
# 13  (0.6987, 3.4072)  (0.6987, 3.4768)  (0.4965, 3.4768)
# 14  (7.9844, 3.3801)  (7.9844, 3.5033)  (0.7894, 3.5033)
# 15  (7.9901, 3.5363)  (7.9901, 3.6596)  (0.4861, 3.6596)
# 16  (1.3516, 3.6926)  (1.3516, 3.8151)  (0.4921, 3.8151)
# 17  (7.8384, 4.0051)  (7.8384, 4.1283)  (0.4891, 4.1283)
# 18  (7.7614, 4.1613)  (7.7614, 4.2846)  (0.4903, 4.2846)
# 19  (7.9845, 4.3176)  (7.9845, 4.4408)  (0.4982, 4.4408)
# 20  (7.9871, 4.4738)  (7.9871, 4.5971)  (0.4949, 4.5971)
# 21  (1.0748, 4.6572)  (1.0748, 4.7268)  (0.4965, 4.7268)
# 22  (7.9871, 4.6301)  (7.9871, 4.7533)  (1.1576, 4.7533)
# 23  (7.6915, 4.7863)  (7.6915, 4.9096)  (0.4994, 4.9096)
# 24  (7.6872, 4.9426)  (7.6872, 5.0658)  (0.4975, 5.0658)
# 25  (7.5375, 5.0988)  (7.5375, 5.2221)  (0.4903, 5.2221)
# 26  (7.6184, 5.2551)  (7.6184, 5.3783)  (0.4975, 5.3783)
# 27  (7.6184, 5.4113)  (7.6184, 5.5346)  (0.4982, 5.5346)
# 28  (7.5428, 5.5676)  (7.5428, 5.6908)  (0.4967, 5.6908)
# 29  (7.9845, 5.7238)  (7.9845, 5.8471)  (0.4933, 5.8471)
# 30  (7.9102, 5.8801)   (7.9102, 6.003)   (0.4975, 6.003)
# 31  (0.6236, 6.0634)   (0.6236, 6.133)   (0.4949, 6.133)
# 32  (1.7976, 6.0363)  (1.7976, 6.1589)  (0.7197, 6.1589)
# 33  (7.9908, 6.3488)  (7.9908, 6.4718)  (0.4899, 6.4718)
# 34   (5.9609, 6.505)  (5.9609, 6.6018)  (0.4967, 6.6018)
# 35  (7.7614, 6.5051)  (7.7614, 6.6276)  (6.0733, 6.6276)
# 36  (7.7641, 6.6613)  (7.7641, 6.7846)  (0.4982, 6.7846)
# 37  (7.6897, 6.8176)  (7.6897, 6.9408)  (0.4949, 6.9408)
# 38  (7.8384, 6.9738)  (7.8384, 7.0971)  (0.4903, 7.0971)
# 39  (7.4636, 7.1301)  (7.4636, 7.2533)  (0.4974, 7.2533)
# 40  (6.0352, 7.2863)  (6.0352, 7.4096)  (0.4903, 7.4096)
# 41  (7.9092, 7.5988)  (7.9092, 7.7221)  (0.4918, 7.7221)
# 42  (7.4477, 7.7551)   (7.4477, 7.878)   (0.4975, 7.878)
# 43  (7.2437, 7.9113)  (7.2437, 8.0346)  (0.4918, 8.0346)
# 44  (3.8792, 8.0676)  (3.8792, 8.1908)  (0.4923, 8.1908)
# 45  (7.9836, 8.3801)  (7.9836, 8.5033)  (0.4918, 8.5033)
# 46  (0.6244, 8.5634)   (0.6244, 8.633)   (0.4922, 8.633)
# 47  (5.2918, 8.5363)  (5.2918, 8.6589)  (0.7133, 8.6589)

# %%
ocr_output
# Out:
# {'title': 'the%20prospect%20of%20a%20continued%20correction.pdf',
#  'format': 'pdf',
#  'isPdf': True,
#  'lines': [{'lines': '\n\nThe Prospect of a Continued Correction',
#    'top_left_XY': (0.4918, 0.5676),
#    'top_right_XY': (3.3007, 0.5676),
#    'bottom_right_XY': (3.3007, 0.6901),
#    'bottom_left_XY': (0.4918, 0.6901)},
#   {'lines': 'Mike Wilson',
#    'top_left_XY': (0.4894, 1.0363),
#    'top_right_XY': (1.2935, 1.0363),
#    'bottom_right_XY': (1.2935, 1.133),
#    'bottom_left_XY': (0.4894, 1.133)},
#   {'lines': "Welcome to Thoughts on the Market. I'm Mike Wilson, Chief Investment Officer and Chief U.S. Equity",
#    'top_left_XY': (0.4891, 1.5051),
#    'top_right_XY': (7.7671, 1.5051),
#    'bottom_right_XY': (7.7671, 1.6283),
#    'bottom_left_XY': (0.4891, 1.6283)},
#   {'lines': "Strategist for Morgan Stanley. Along with my colleagues bringing you a variety of perspectives, I'll",
#    'top_left_XY': (0.4934, 1.6613),
#    'top_right_XY': (7.9107, 1.6613),
#    'bottom_right_XY': (7.9107, 1.7846),
#    'bottom_left_XY': (0.4934, 1.7846)},
#   {'lines': "be talking about the latest trends in the financial marketplace. It's Wednesday, February 23rd at 11",
#    'top_left_XY': (0.4967, 1.8176),
#    'top_right_XY': (7.9121, 1.8176),
#    'bottom_right_XY': (7.9121, 1.9408),
#    'bottom_left_XY': (0.4967, 1.9408)},
#   {'lines': 'a.m.',
#    'top_left_XY': (0.4949, 2.0009),
#    'top_right_XY': (0.7568, 2.0009),
#    'bottom_right_XY': (0.7568, 2.0705),
#    'bottom_left_XY': (0.4949, 2.0705)},
#   {'lines': "in New York. So let's get after it.",
#    'top_left_XY': (0.8692, 1.9738),
#    'top_right_XY': (3.4332, 1.9738),
#    'bottom_right_XY': (3.4332, 2.0971),
#    'bottom_left_XY': (0.8692, 2.0971)},
#   {'lines': 'This past week tensions around Russia/Ukraine dominated the headlines. When unpredictable events like',
#    'top_left_XY': (0.4918, 2.2863),
#    'top_right_XY': (7.9871, 2.2863),
#    'bottom_right_XY': (7.9871, 2.4089),
#    'bottom_left_XY': (0.4918, 2.4089)},
#   {'lines': "this occur, it's easy to simply throw up one's arms and blame all price action on it. However, we're",
#    'top_left_XY': (0.4903, 2.4426),
#    'top_right_XY': (7.9128, 2.4426),
#    'bottom_right_XY': (7.9128, 2.5655),
#    'bottom_left_XY': (0.4903, 2.5655)},
#   {'lines': "not so sure that's a good idea, particularly in the current environment of Fed tightening and slowing",
#    'top_left_XY': (0.4967, 2.5988),
#    'top_right_XY': (7.9896, 2.5988),
#    'bottom_right_XY': (7.9896, 2.7221),
#    'bottom_left_XY': (0.4967, 2.7221)},
#   {'lines': 'growth.',
#    'top_left_XY': (0.4923, 2.7559),
#    'top_right_XY': (0.9798, 2.7559),
#    'bottom_right_XY': (0.9798, 2.8783),
#    'bottom_left_XY': (0.4923, 2.8783)},
#   {'lines': 'From here, though, the depth and duration of the ongoing correction will be determined primarily by',
#    'top_left_XY': (0.4997, 3.0676),
#    'top_right_XY': (7.8414, 3.0676),
#    'bottom_right_XY': (7.8414, 3.1908),
#    'bottom_left_XY': (0.4997, 3.1908)},
#   {'lines': 'the magnitude of the slowdown in the first half of 2022. While the Russia/Ukraine situation obviously',
#    'top_left_XY': (0.4903, 3.2238),
#    'top_right_XY': (7.9901, 3.2238),
#    'bottom_right_XY': (7.9901, 3.3471),
#    'bottom_left_XY': (0.4903, 3.3471)},
#   {'lines': 'can',
#    'top_left_XY': (0.4965, 3.4072),
#    'top_right_XY': (0.6987, 3.4072),
#    'bottom_right_XY': (0.6987, 3.4768),
#    'bottom_left_XY': (0.4965, 3.4768)},
#   {'lines': "make this slowdown even worse, ultimately, we think that preexisting fundamental risks we've been",
#    'top_left_XY': (0.7894, 3.3801),
#    'top_right_XY': (7.9844, 3.3801),
#    'bottom_right_XY': (7.9844, 3.5033),
#    'bottom_left_XY': (0.7894, 3.5033)},
#   {'lines': 'focused on for months will be the primary drivers, particularly as geopolitical concerns are now very',
#    'top_left_XY': (0.4861, 3.5363),
#    'top_right_XY': (7.9901, 3.5363),
#    'bottom_right_XY': (7.9901, 3.6596),
#    'bottom_left_XY': (0.4861, 3.6596)},
#   {'lines': 'much priced.',
#    'top_left_XY': (0.4921, 3.6926),
#    'top_right_XY': (1.3516, 3.6926),
#    'bottom_right_XY': (1.3516, 3.8151),
#    'bottom_left_XY': (0.4921, 3.8151)},
#   {'lines': "While most economic and earnings forecasts do reflect the slowdown from last year's torrid pace, we",
#    'top_left_XY': (0.4891, 4.0051),
#    'top_right_XY': (7.8384, 4.0051),
#    'bottom_right_XY': (7.8384, 4.1283),
#    'bottom_left_XY': (0.4891, 4.1283)},
#   {'lines': "think there's a growing risk of greater disappointment in both. We've staked our case primarily on",
#    'top_left_XY': (0.4903, 4.1613),
#    'top_right_XY': (7.7614, 4.1613),
#    'bottom_right_XY': (7.7614, 4.2846),
#    'bottom_left_XY': (0.4903, 4.2846)},
#   {'lines': 'slowing consumer demand as confidence remains low thanks to the generationally high inflation in just',
#    'top_left_XY': (0.4982, 4.3176),
#    'top_right_XY': (7.9845, 4.3176),
#    'bottom_right_XY': (7.9845, 4.4408),
#    'bottom_left_XY': (0.4982, 4.4408)},
#   {'lines': 'about everything the consumer needs and wants. Many investors we speak with remain more convinced the',
#    'top_left_XY': (0.4949, 4.4738),
#    'top_right_XY': (7.9871, 4.4738),
#    'bottom_right_XY': (7.9871, 4.5971),
#    'bottom_left_XY': (0.4949, 4.5971)},
#   {'lines': 'consumer',
#    'top_left_XY': (0.4965, 4.6572),
#    'top_right_XY': (1.0748, 4.6572),
#    'bottom_right_XY': (1.0748, 4.7268),
#    'bottom_left_XY': (0.4965, 4.7268)},
#   {'lines': 'will hold up better than the confidence surveys suggest. After all, high frequency data like',
#    'top_left_XY': (1.1576, 4.6301),
#    'top_right_XY': (7.9871, 4.6301),
#    'bottom_right_XY': (7.9871, 4.7533),
#    'bottom_left_XY': (1.1576, 4.7533)},
#   {'lines': 'retail sales and credit card data remain robust, while many consumer facing companies continue to',
#    'top_left_XY': (0.4994, 4.7863),
#    'top_right_XY': (7.6915, 4.7863),
#    'bottom_right_XY': (7.6915, 4.9096),
#    'bottom_left_XY': (0.4994, 4.9096)},
#   {'lines': 'indicate no slowdown in demand, at least not yet. However, most of our leading indicators suggest',
#    'top_left_XY': (0.4975, 4.9426),
#    'top_right_XY': (7.6872, 4.9426),
#    'bottom_right_XY': (7.6872, 5.0658),
#    'bottom_left_XY': (0.4975, 5.0658)},
#   {'lines': 'that the risk of consumer slowdown remains higher than normal. Secondarily, but perhaps just as',
#    'top_left_XY': (0.4903, 5.0988),
#    'top_right_XY': (7.5375, 5.0988),
#    'bottom_right_XY': (7.5375, 5.2221),
#    'bottom_left_XY': (0.4903, 5.2221)},
#   {'lines': 'importantly, is the fact that supply is now rising. While this will alleviate some of the supply',
#    'top_left_XY': (0.4975, 5.2551),
#    'top_right_XY': (7.6184, 5.2551),
#    'bottom_right_XY': (7.6184, 5.3783),
#    'bottom_left_XY': (0.4975, 5.3783)},
#   {'lines': 'shortages, it could also lead to a return of price discounting for many goods where inflationary',
#    'top_left_XY': (0.4982, 5.4113),
#    'top_right_XY': (7.6184, 5.4113),
#    'bottom_right_XY': (7.6184, 5.5346),
#    'bottom_left_XY': (0.4982, 5.5346)},
#   {'lines': "pressures have been the greatest. That's potentially a problem for margins. It's also a risk to",
#    'top_left_XY': (0.4967, 5.5676),
#    'top_right_XY': (7.5428, 5.5676),
#    'bottom_right_XY': (7.5428, 5.6908),
#    'bottom_left_XY': (0.4967, 5.6908)},
#   {'lines': 'demand, in our view, if the improved supply reveals a much greater level of double ordering than what',
#    'top_left_XY': (0.4933, 5.7238),
#    'top_right_XY': (7.9845, 5.7238),
#    'bottom_right_XY': (7.9845, 5.8471),
#    'bottom_left_XY': (0.4933, 5.8471)},
#   {'lines': 'is currently anticipated. In short, the order books?-?i.e. the demand picture?-?may not be as robust',
#    'top_left_XY': (0.4975, 5.8801),
#    'top_right_XY': (7.9102, 5.8801),
#    'bottom_right_XY': (7.9102, 6.003),
#    'bottom_left_XY': (0.4975, 6.003)},
#   {'lines': 'as',
#    'top_left_XY': (0.4949, 6.0634),
#    'top_right_XY': (0.6236, 6.0634),
#    'bottom_right_XY': (0.6236, 6.133),
#    'bottom_left_XY': (0.4949, 6.133)},
#   {'lines': 'people believe.',
#    'top_left_XY': (0.7197, 6.0363),
#    'top_right_XY': (1.7976, 6.0363),
#    'bottom_right_XY': (1.7976, 6.1589),
#    'bottom_left_XY': (0.7197, 6.1589)},
#   {'lines': 'Overall, the technical picture is mixed also within U.S. equities. Rarely have we witnessed such weak',
#    'top_left_XY': (0.4899, 6.3488),
#    'top_right_XY': (7.9908, 6.3488),
#    'bottom_right_XY': (7.9908, 6.4718),
#    'bottom_left_XY': (0.4899, 6.4718)},
#   {'lines': 'breath and havoc under the surface when the S&P 500 is down less than 10%.',
#    'top_left_XY': (0.4967, 6.505),
#    'top_right_XY': (5.9609, 6.505),
#    'bottom_right_XY': (5.9609, 6.6018),
#    'bottom_left_XY': (0.4967, 6.6018)},
#   {'lines': 'In our experience, when',
#    'top_left_XY': (6.0733, 6.5051),
#    'top_right_XY': (7.7614, 6.5051),
#    'bottom_right_XY': (7.7614, 6.6276),
#    'bottom_left_XY': (6.0733, 6.6276)},
#   {'lines': 'such a divergence like this happens, it typically ends with the primary index catching down to the',
#    'top_left_XY': (0.4982, 6.6613),
#    'top_right_XY': (7.7641, 6.6613),
#    'bottom_right_XY': (7.7641, 6.7846),
#    'bottom_left_XY': (0.4982, 6.7846)},
#   {'lines': 'average stock. In short, this correction looks incomplete to us. Nevertheless, we also appreciate',
#    'top_left_XY': (0.4949, 6.8176),
#    'top_right_XY': (7.6897, 6.8176),
#    'bottom_right_XY': (7.6897, 6.9408),
#    'bottom_left_XY': (0.4949, 6.9408)},
#   {'lines': 'that equity markets are very oversold and sentiment is bearish even if positioning is not. With the',
#    'top_left_XY': (0.4903, 6.9738),
#    'top_right_XY': (7.8384, 6.9738),
#    'bottom_right_XY': (7.8384, 7.0971),
#    'bottom_left_XY': (0.4903, 7.0971)},
#   {'lines': 'Russia Ukraine situation now weighing heavily on equity markets, relief would likely lead to a',
#    'top_left_XY': (0.4974, 7.1301),
#    'top_right_XY': (7.4636, 7.1301),
#    'bottom_right_XY': (7.4636, 7.2533),
#    'bottom_left_XY': (0.4974, 7.2533)},
#   {'lines': 'tactical rally, but we acknowledge that uncertainty remains extremely high.',
#    'top_left_XY': (0.4903, 7.2863),
#    'top_right_XY': (6.0352, 7.2863),
#    'bottom_right_XY': (6.0352, 7.4096),
#    'bottom_left_XY': (0.4903, 7.4096)},
#   {'lines': "The bottom line for us is that we really don't have a strong view on the Russia/Ukraine situation as",
#    'top_left_XY': (0.4918, 7.5988),
#    'top_right_XY': (7.9092, 7.5988),
#    'bottom_right_XY': (7.9092, 7.7221),
#    'bottom_left_XY': (0.4918, 7.7221)},
#   {'lines': 'it relates to the equity markets. However, we think a lot of bad news is priced at this point.',
#    'top_left_XY': (0.4975, 7.7551),
#    'top_right_XY': (7.4477, 7.7551),
#    'bottom_right_XY': (7.4477, 7.878),
#    'bottom_left_XY': (0.4975, 7.878)},
#   {'lines': 'Therefore, we would look to sell strength into the end of the month if markets rally on the',
#    'top_left_XY': (0.4918, 7.9113),
#    'top_right_XY': (7.2437, 7.9113),
#    'bottom_right_XY': (7.2437, 8.0346),
#    'bottom_left_XY': (0.4918, 8.0346)},
#   {'lines': 'geopolitical risk failing to escalate further.',
#    'top_left_XY': (0.4923, 8.0676),
#    'top_right_XY': (3.8792, 8.0676),
#    'bottom_right_XY': (3.8792, 8.1908),
#    'bottom_left_XY': (0.4923, 8.1908)},
#   {'lines': 'Thanks for listening. If you enjoy Thoughts on the Market, please take a moment to rate and review us',
#    'top_left_XY': (0.4918, 8.3801),
#    'top_right_XY': (7.9836, 8.3801),
#    'bottom_right_XY': (7.9836, 8.5033),
#    'bottom_left_XY': (0.4918, 8.5033)},
#   {'lines': 'on',
#    'top_left_XY': (0.4922, 8.5634),
#    'top_right_XY': (0.6244, 8.5634),
#    'bottom_right_XY': (0.6244, 8.633),
#    'bottom_left_XY': (0.4922, 8.633)},
#   {'lines': 'the Apple Podcasts app. It helps more people to find the show.',
#    'top_left_XY': (0.7133, 8.5363),
#    'top_right_XY': (5.2918, 8.5363),
#    'bottom_right_XY': (5.2918, 8.6589),
#    'bottom_left_XY': (0.7133, 8.6589)}],
#  'corpus': "\n\nThe Prospect of a Continued Correction\nMike Wilson\nWelcome to Thoughts on the Market. I'm Mike Wilson, Chief Investment Officer and Chief U.S. Equity\nStrategist for Morgan Stanley. Along with my colleagues bringing you a variety of perspectives, I'll\nbe talking about the latest trends in the financial marketplace. It's Wednesday, February 23rd at 11\na.m.\nin New York. So let's get after it.\nThis past week tensions around Russia/Ukraine dominated the headlines. When unpredictable events like\nthis occur, it's easy to simply throw up one's arms and blame all price action on it. However, we're\nnot so sure that's a good idea, particularly in the current environment of Fed tightening and slowing\ngrowth.\nFrom here, though, the depth and duration of the ongoing correction will be determined primarily by\nthe magnitude of the slowdown in the first half of 2022. While the Russia/Ukraine situation obviously\ncan\nmake this slowdown even worse, ultimately, we think that preexisting fundamental risks we've been\nfocused on for months will be the primary drivers, particularly as geopolitical concerns are now very\nmuch priced.\nWhile most economic and earnings forecasts do reflect the slowdown from last year's torrid pace, we\nthink there's a growing risk of greater disappointment in both. We've staked our case primarily on\nslowing consumer demand as confidence remains low thanks to the generationally high inflation in just\nabout everything the consumer needs and wants. Many investors we speak with remain more convinced the\nconsumer\nwill hold up better than the confidence surveys suggest. After all, high frequency data like\nretail sales and credit card data remain robust, while many consumer facing companies continue to\nindicate no slowdown in demand, at least not yet. However, most of our leading indicators suggest\nthat the risk of consumer slowdown remains higher than normal. Secondarily, but perhaps just as\nimportantly, is the fact that supply is now rising. While this will alleviate some of the supply\nshortages, it could also lead to a return of price discounting for many goods where inflationary\npressures have been the greatest. That's potentially a problem for margins. It's also a risk to\ndemand, in our view, if the improved supply reveals a much greater level of double ordering than what\nis currently anticipated. In short, the order books?-?i.e. the demand picture?-?may not be as robust\nas\npeople believe.\nOverall, the technical picture is mixed also within U.S. equities. Rarely have we witnessed such weak\nbreath and havoc under the surface when the S&P 500 is down less than 10%.\nIn our experience, when\nsuch a divergence like this happens, it typically ends with the primary index catching down to the\naverage stock. In short, this correction looks incomplete to us. Nevertheless, we also appreciate\nthat equity markets are very oversold and sentiment is bearish even if positioning is not. With the\nRussia Ukraine situation now weighing heavily on equity markets, relief would likely lead to a\ntactical rally, but we acknowledge that uncertainty remains extremely high.\nThe bottom line for us is that we really don't have a strong view on the Russia/Ukraine situation as\nit relates to the equity markets. However, we think a lot of bad news is priced at this point.\nTherefore, we would look to sell strength into the end of the month if markets rally on the\ngeopolitical risk failing to escalate further.\nThanks for listening. If you enjoy Thoughts on the Market, please take a moment to rate and review us\non\nthe Apple Podcasts app. It helps more people to find the show."}

# %% [markdown]
# ---

# %% [markdown]
# # OpenAI NLG GPT-3

# %%
# License Key
openai.api_key = os.environ.get("OPENAI_KEY")

# list engines
engines = openai.Engine.list()
print([i.id for i in engines.data])

# %%
def play(prompt):

    if prompt is None or prompt.strip()=="":
        return Exception("Incorrect prompt")

    response = openai.Completion.create(
        engine="text-davinci-001",
        prompt=prompt,
        temperature=0.01,   # sampling temp, higher values means the model will take more risks, 0.9-creative, 0-well-defined.
        max_tokens=250,     # max number of tokens to generate in completion API.
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0)

    # >>> REPSONE JSON <<<
    # print(response, "\n")
    
    # print the nl generated using davinci gpt-3 model
    print("-"*100, "\nprompt: ", prompt.split("\n\n###\n\n")[2])
    print("\nResponse\n###\n", response.choices[0].text.strip().strip("\n").strip(), "\n###")
    return

# %% [markdown]
# #### Examples

# %%
# The Prospect of a Continued Correction by Mike Wilson Podcast Transcript

demo_doc = """YOUR DOCUMENT GOES HERE"""

# prepare this as 'ocr-result'
demo_doc = "TEXT: \n\n###\n\n"  + demo_doc.strip("\n").strip() + "\n\n###\n\n"

# %%
play(demo_doc + "Who is the author in this?")

# %%
play(demo_doc + "Summarize TEXT in 500 words.")

# %%
play(demo_doc + "Generate 5 FAQs from the TEXT.")

# %%
play(demo_doc + "Find important words in TEXT")

# %%
play(demo_doc + "Find important phrases in the TEXT.")

# %%
play(demo_doc + "Find sentiment words in the TEXT.")

# %%
# 50% confidence
play(demo_doc + "Find abbreviation in the TEXT.")

# %% [markdown]
# ### OpenAI Module

# %%
class extract_metadata:
    
    def __init__(self, OPENAI_INSTANCE, OCR_RESULT_JSON):

        if not OCR_RESULT_JSON:
            raise Exception("ERROR: Please pass a 'OCR Ouptut'")

        # License key
        self.openai = OPENAI_INSTANCE
        self.openai.api_key = os.environ.get("OPENAI_KEY")
        
        # :: config ::
        self.engine = "text-davinci-001"   # engine choose gpt3 from list, older - gpt2.1
        self.temp = 0.01          # higher values means the model will take more risks, 0.9 means creative, 0 is well-defined.
        self.max_tokens = 250     # max number of tokens to generate in completion API.
        self.doc_token_size = 1450  # free license supports upto 2049 tokens
        
        # ocr'ed document
        self.doc_title = OCR_RESULT_JSON['title']
        corpus = OCR_RESULT_JSON['corpus'].strip("\n\n").strip("\n")
        corpus = " ".join(corpus.split(" ")[:self.doc_token_size])
        self.doc = "TEXT:\n\n###\n\n" + corpus + "\n\n###\n\n"
        
        return
    
    
    def run_on_doc(self, prompt, insight_type=None):

        # max words
        # max_word_limit = self.max_tokens
        # if insight_type=="summary":
        #    max_word_limit = 500
            
        # run openAI api
        response = self.openai.Completion.create(
            engine=self.engine,
            prompt=prompt,
            temperature=self.temp,
            max_tokens=self.max_tokens,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0)
        
        # >>> REPSONE JSON <<<
        output_json = response
        # print(output_json)
        
        available_choices = len(response.choices)
        if available_choices > 1:
            selected_choice = random.choice(response.choices)
        else:
            selected_choice = response.choices[0]
            
        # Final output
        output = selected_choice.text.strip().strip("\n").strip()
        # print("Available choices --->", available_choices)
        # print("Response\n###\n", output, "\n###")
        
        return output
    
    
    def execute(self, prompt, insight=None):
        
        prompt_mapping = {
            
            "default-summary": "Summarize TEXT in 300 words.",
            "default-faq": "Generate 5 FAQs from the TEXT.",
            "default-keypoints": "Tl;dr",
            "default-keywords": "Find important words in the TEXT.",
            "default-phrases": "Find important phrases in the TEXT.",
            "default-sentiment": "Find sentiment words in the TEXT.",
            "default-abbrv": "Find abbreviations in the TEXT."
        }
        
        if insight is None and (prompt is None or str(prompt).strip()=="" or str(prompt)=="nan"):
            return Exception("ERROR: Incorrect or no prompt passed!")
        
        if insight and insight.lower().strip() in prompt_mapping.keys(): 
            insight = insight.lower().strip()
            input_text = self.doc + prompt_mapping[insight]
            result = self.run_on_doc(input_text).strip("\n").strip()

        else:
            # USER INPUT (FAQ)
            user_input = str(prompt).rstrip(" ").rstrip(".").rstrip(":").rstrip("-").rstrip(",").rstrip("?").rstrip("!")
            input_text = self.doc + user_input + " in the TEXT."
            result = self.run_on_doc(input_text).strip("\n").strip()
        
        print(input_text.split("###")[2], ":\n\n", result, "\n", "--"*50)
        return result

# %%
# demo

run_docAI = extract_metadata(openai, ocr_output)

run_docAI.execute("Who is the author in this?")
run_docAI.execute("Summarize TEXT in 500 words.")
run_docAI.execute("What is Mike Wilson's view on direction of market?")
run_docAI.execute("Generate 5 FAQs in this.")
run_docAI.execute("\n\nTl;dr")
run_docAI.execute("Find important words..")
run_docAI.execute("Find important phrases?")
run_docAI.execute("Find sentiment words")
run_docAI.execute("Find abbreviation.")
# Out:
# Who is the author in this in the TEXT. :
#
#  Mike Wilson
#  ----------------------------------------------------------------------------------------------------
#
#
# Summarize TEXT in 500 words in the TEXT. :
#
#  The market is correcting from its high in January, with the main drivers being slowing growth and rising supply. The depth and duration of the correction will be determined by the magnitude of the slowdown in the first half of 2022, which will be exacerbated by the Russia/Ukraine situation. However, there are also preexisting fundamental risks that will continue to drive the market, such as slowing consumer demand and rising supply. The technical picture is mixed, with the S&P 500 down less than 10% but a divergence between the index and the average stock. Relief from the Russia/Ukraine situation could lead to a tactical rally, but uncertainty remains high.
#  ----------------------------------------------------------------------------------------------------
#
#
# What is Mike Wilson's view on direction of market in the TEXT. :
#
#  Mike Wilson believes that the depth and duration of the ongoing correction will be determined primarily by the magnitude of the slowdown in the first half of 2022. While the Russia/Ukraine situation obviously can make this slowdown even worse, ultimately, he thinks that preexisting fundamental risks will be the primary drivers.
#  ----------------------------------------------------------------------------------------------------
#
#
# Generate 5 FAQs in this in the TEXT. :
#
#  1. What is the current market environment like?
# 2. What is the depth and duration of the ongoing correction?
# 3. What are the primary drivers of the slowdown?
# 4. What are the risks to consumer demand?
# 5. What is the technical picture for U.S. equities?
#  ----------------------------------------------------------------------------------------------------
#
#
#
#
# Tl;dr in the TEXT. :
#
#  The market is correcting because there are concerns about the economy slowing down, and specifically because of concerns about the consumer demand and the return of price discounting. The technical picture is mixed, and the market could still go down further.
#  ----------------------------------------------------------------------------------------------------
#
#
# Find important words in the TEXT. :
#
#  The Prospect of a Continued Correction
#
# tensions around Russia/Ukraine dominated the headlines
#
# From here, though, the depth and duration of the ongoing correction will be determined primarily by the magnitude of the slowdown in the first half of 2022.
#
# While most economic and earnings forecasts do reflect the slowdown from last year's torrid pace, we think there's a growing risk of greater disappointment in both.
#
# We've staked our case primarily on slowing consumer demand as confidence remains low thanks to the generationally high inflation in just about everything the consumer needs and wants.
#
# Many investors we speak with remain more convinced the consumer will hold up better than the confidence surveys suggest.
#
# However, most of our leading indicators suggest that the risk of consumer slowdown remains higher than normal.
#
# Secondarily, but perhaps just as importantly, is the fact that supply is now rising.
#
# While this will alleviate some of the supply shortages, it could also lead to a return of price discounting for many goods where inflationary pressures have been the greatest.
#
# That's potentially a problem for margins.
#
# It's also a risk to demand, in our view, if the improved supply reveals a much greater level of
#  ----------------------------------------------------------------------------------------------------
#
#
# Find important phrases in the TEXT. :
#
#  "The depth and duration of the ongoing correction will be determined primarily by the magnitude of the slowdown in the first half of 2022."
#
# "While most economic and earnings forecasts do reflect the slowdown from last year's torrid pace, we think there's a growing risk of greater disappointment in both."
#
# "Secondarily, but perhaps just as importantly, is the fact that supply is now rising."
#
# "In short, the order books?-?i.e. the demand picture?-?may not be as robust as people believe."
#  ----------------------------------------------------------------------------------------------------
#
#
# Find sentiment words in the TEXT. :
#
#  tensions, headline, market, strategists, focus, fundamentals, drivers, magnitude, slowdown, first, half, 2022, Russia, Ukraine, situation, priced, consumer, demand, confidence, surveys, indicators, ordering, double, incomplete, oversold, relief, rally, uncertainty
#  ----------------------------------------------------------------------------------------------------
#
#
# Find abbreviation in the TEXT. :
#
#  N/A
#  ----------------------------------------------------------------------------------------------------
# 'N/A'

# %% [markdown]
# ----

# %% [markdown]
# # Search  (Lucene based keyword search service)

# %%
def initiate_search():
    load_config("azure_search_config.json")
    global search_endpoint, search_index_name, search_key, search_client
    search_endpoint = os.environ.get("SEARCH_ENDPOINT")
    search_index_name = os.environ.get("INDEX_NAME")
    search_key = os.environ.get("SEARCH_KEY")
    search_client = SearchClient(service_endpoint, index_name, AzureKeyCredential(key))


def keyword_query(query):
    results = search_client.search(search_text=query)
    final_result = list()
    count = 1
    for result in results:
        doc = dict()
        doc["metadata_content_type"] = result["metadata_content_type"]
        doc["metadata_storage_name"] = result["metadata_storage_name"]
        doc["metadata_storage_path"] = result["metadata_storage_path"]
        doc["@search.score"] = result["@search.score"] 
        final_result.append(doc)
    return final_result

# %%
# search a 'query'

initiate_search()    
keyword_query("australia")

# %% [markdown]
# ----
# ----

# %% [markdown]
# # API TESTING

# %% [markdown]
# #### OCR & OpenAI API

# %%
url = "http://0.0.0.0:5002/docai/version"
r = requests.get(url)

print(r.text)

# %%
url = "http://0.0.0.0:5002/docai/run_ocr"
payload = {
    "file_path": "https://azure-container-name.blob.core.windows.net/documents/sample.pdf"
}

r = requests.post(url, json=payload)
print(r.status_code)

ocr_response_json = r.json()   # upload this in azure-blob

# %%
# Option 1 - When user types a input query

url = "http://0.0.0.0:5002/docai/extract_insights"
payload = {
    "document": ocr_response_json,
    "query": "Generate summary for this in 100 words!"
}

r = requests.post(url, json=payload)
print(r.text)

# %%
# Option 2 - When user clicks on "SUMMARY" button ---

url = "http://0.0.0.0:5002/docai/extract_insights"
payload = {
    "document": ocr_response_json,
    "query": "",
    "default_insight": "default-summary"
}

r = requests.post(url, json=payload)
print(r.json())

# %%
# Option 2.2 - When user clicks on "GENERATE FAQs" button ---

url = "http://0.0.0.0:5002/docai/extract_insights"
payload = {
    "document": ocr_response_json,
    "query": "",
    "default_insight": "default-faq"
}

r = requests.post(url, json=payload)
print(r.json())

# %%
# Option 2.3 - When user clicks on "GENERATE MAIN KEYPOINYS" button ---

url = "http://0.0.0.0:5002/docai/extract_insights"
payload = {
    "document": ocr_response_json,
    "query": "",
    "default_insight": "default-keypoints"
}

r = requests.post(url, json=payload)
print(r.json())

# %%
# Option 2.4 - When user clicks on "GENERATE KEYWORDS" button ---

url = "http://0.0.0.0:5002/docai/extract_insights"
payload = {
    "document": ocr_response_json,
    "query": "",
    "default_insight": "default-keywords"
}

r = requests.post(url, json=payload)
print(r.json())

# %%
# Option 2.5 - When user clicks on "GENERATE SENTIMENT WORDS" button ---

url = "http://0.0.0.0:5002/docai/extract_insights"
payload = {
    "document": ocr_response_json,
    "query": "",
    "default_insight": "default-sentiment"
}

r = requests.post(url, json=payload)
print(r.json())

# %%
# Option 2.6 - When user clicks on "GENERATE ABBREVIATIONS" button ---

url = "http://0.0.0.0:5002/docai/extract_insights"
payload = {
    "document": ocr_response_json,
    "query": "",
    "default_insight": "default-abbrv"
}

r = requests.post(url, json=payload)
print(r.json())

# %% [markdown]
# #### Search API

# %%
# Testing API

response = requests.get("http://127.0.0.1:5000/search/australia finance")
response.json()
